# %% [markdown]
# # Week Three Homework
# ## 1. What is an algorithm?
# An **algorithm** is a series of instructions or steps for doing something.
#
# ## 2. Variable names may not start with certain characters - name two.
# Variable names can't start with numbers or special characters other than underscores.
#
# ## 3. What is a Semantic error?
# **Semantic errors** are what happens when your code is correct but nonsensical. The program will run but the output doesn't make sense or isn't the sort of output you are looking for.
#
# ## 4. What is the #1 rule of coding / debugging?
# Complexity is the enemy of efficiency.
#
# ## 5. List 5 Python reserved words.
# TRUE, FALSE, if, else, import

# %%
#Data Types

#6. Write a multi-line string with your name, favorite food, and dream job on 3 different lines
answer6 = """My name is Kimberly.
My favorite food is eggplant parmigiana.
When I was a kid I wanted to be an astronaut."""

#7. Assign 5 different data types to 5 different variables. At least one datatype must be a string
astring = "bumblebee"
aninteger = 5
afloat = 5.6
alist = ["colorless", "green", "furious"]
aboolean = True

#Print the length of your string
print(len(astring))

#Print the index value of the 4th character in your string
print("The 4th character in my string is ", astring[3])

#8. Create a new variable called savvy, and assign it the string with this phrase "Learning Data Analytics and Python is Awesome!"
savvy = "Learning Data Analytics and Python is Awesome!"

#Return a range of characters that slices the above string from the beginning of "ing" up to before "and"
print(savvy[5:23])

#Replace "Awesome" with "great" in the string
print(savvy.replace ("Awesome", "great"))

#Test and print the savvy string to see it contains "Python"
if "Python" in savvy:
    print("Yes, 'Python' is present.")

#9. Create and assign 3 more variables called name, age and length using the multi-variable naming method
name = "Kimberly"
age = 47
length = "5 feet, 4 inches"

#Format a new string called 'miniBio' using variables in curly brackets to complete this phrase... "Hi my name is (name), I am (tall) and (so) old today."
miniBio = "Hi, my name is {}, I am {} tall and {} years old today."

#Print 'miniBio'
print(miniBio.format(name, length, age))

#Cast and print the age variable to a float
age = float(47)
print(age)
# Out:
# 9
# The 4th character in my string is  b
# ing Data Analytics
# Learning Data Analytics and Python is great!
# Yes, 'Python' is present.
# Hi, my name is Kimberly, I am 5 feet, 4 inches tall and 47 years old today.
# 47.0

# %%
# Complex Data Types
# 10. Create a list of at least 5 elements of mixed data types
newlist = ["red", 4, "tall", 99, "Barbara"]

# Replace a part of it with something else
newlist[0:2] = ["blue", 7]

# Append or insert several more items to the list
newlist.append("yellow")
newlist.append(33)

# Find and print the length of the list
print("List length = ", len(newlist))

# Slice a sub-section of the 1st list, and save it to a different 2nd list
newlist2 = newlist[-3:]

# Print the 2nd list
print(newlist2)

# Extend your original list with the 2nd list sliced above
newlist.extend(newlist2)

# Create a new list called "simList" containing at least 5 elements of the same data type, either string, integer, float, or Boolean
simlist = ["one", "two", "three", "four", "five"]

# Sort "simList", and print the list
simlist.sort()
print(simlist)

# Copy the "simList" list to another 3rd list
simlist2 = simlist.copy()

# Add the 2nd and 3rd lists together into a 4th list
simlist3 = simlist + simlist2

# 11. Create a tuple of about 5 elements
sampleTuple = ("square", "circle", "triangle", "rhombus", "hexagon")

# Multiply your tuple by 3 and save it to a new 2nd tuple
multipliedTuple = sampleTuple * 3

# Access and print the 12th element from the 2nd tuple
print(multipliedTuple[11])

# Sort the 2nd tuple and print it
sorted(multipliedTuple)

# Copy 4 specific elements from your 2nd tuple to a new 3nd tuple
reducedTuple = multipliedTuple[:4]

# Unpack the 3rd tuple into 4 variables and print these variables
(shape1, shape2, shape3, shape4) = reducedTuple
print("shape1 =", shape1, "shape2 =", shape2, "shape3 =", shape3, "shape4 =", shape4)

# Create a 4th tuple with single item 50 and print this tuple
shortTuple = (50, )
print(shortTuple)

# Add the 2nd and 3rd tuple together into a 5th tuple and print the tuple
finalTuple = multipliedTuple + reducedTuple
print(finalTuple)

# 12. Create a set of about 3 elements
set1 = {"brown", "green", "red"}

# Add a list of fruits to the above set and print the result
fruitSet = {"banana", "strawberry", "kiwi"}
set1.update(fruitSet)
print(set1)

# Add a car element to your set
set1.add("Bugatti")

# Create a 2nd set with a few odd items
set2 = {"crystal ball", "cursed doll", "black cat bone"}

# Save the union of 1st set and 2nd set to a 3rd set
set3 = set1.union(set2)

# Pop an element from the 2nd set, and print the remainder of the set
set2.pop()
print(set2)

# Clear the 1st set and print the result
set1.clear()
print(set1)

# Discard an element, and remove another element from the 3rd set
set3.discard("brown")
set3.remove("red")

# Print the remainder of the 3rd set
print(set3)

# 13. Create a dictionary with at least 5 values of different data types
dict1 = {"pet_name": "Bandicoot",
         "pet_type": "dog",
         "pet_age": 7,
         "pet_weight_lbs": 75,
         "favorite_toy_type": "stuffed animals"}

# Print out 1 value
name1 = dict1.get("pet_name")
print(name1)

# Replace any one value in your dictionary with your name
dict1.update({"pet_name": "Kimberly"})

# Add your favorite color to the dictionary
dict1.update({"favorite_color": "green"})

# Add a list, tuple or set to your dictionary
dict1.update({"likes": ("dogs", "cats", "bats")})

# Print a list of the dictionary keys
print(dict1.keys())

# Print a list of the dictionary values
print(dict1.values())

# Copy your 1st dictionary into a 2nd dictionary
dict2 = dict1.copy()

# Pop an item from the 2nd dictionary, and print the dictionary
dict2.popitem()
print(dict2)

# Remove all the elements from the 2nd dictionary and print the result
dict2.clear()
print(dict2)
# Out:
# List length =  7
# ['Barbara', 'yellow', 33]
# ['five', 'four', 'one', 'three', 'two']
# circle
# shape1 = square shape2 = circle shape3 = triangle shape4 = rhombus
# (50,)
# ('square', 'circle', 'triangle', 'rhombus', 'hexagon', 'square', 'circle', 'triangle', 'rhombus', 'hexagon', 'square', 'circle', 'triangle', 'rhombus', 'hexagon', 'square', 'circle', 'triangle', 'rhombus')
# {'banana', 'kiwi', 'green', 'brown', 'strawberry', 'red'}
# {'crystal ball', 'black cat bone'}
# set()
# {'cursed doll', 'strawberry', 'banana', 'black cat bone', 'Bugatti', 'kiwi', 'green', 'crystal ball'}
# Bandicoot
# dict_keys(['pet_name', 'pet_type', 'pet_age', 'pet_weight_lbs', 'favorite_toy_type', 'favorite_color', 'likes'])
# dict_values(['Kimberly', 'dog', 7, 75, 'stuffed animals', 'green', ('dogs', 'cats', 'bats')])
# {'pet_name': 'Kimberly', 'pet_type': 'dog', 'pet_age': 7, 'pet_weight_lbs': 75, 'favorite_toy_type': 'stuffed animals', 'favorite_color': 'green'}
# {}
